# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(y, a):
    b = (153*187 - 50)/(32*187)
    return (((36*(a - b*y*y))**0.5)/(187**0.5)) + ((30*y)/(4*187))

ydata = np.linspace(-1000, 1000, 10000)
xdata = f(ydata, 10000000)

plt.plot(ydata, xdata)
